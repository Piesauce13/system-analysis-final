# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - [1. Exploring The Dataset](#a)
#     - [1.1 Load The Datset](#1.1)
#     - [1.2 Data Description](#1.2)
# - [2. Data Cleaning](#2)
#     - [2.1 Missing Value](#2.1)
#     - [2.2 Duplicated](#2.2)
#     - [2.3 Outliter](#2.3)

# %% [markdown]
# ## 1. Exploring the datasert
# ### 1.1 Load the Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ManonYa09/Data_analysis_with_pandas/main/Data/Ecommerce%20Purchases.csv')
df.head(1)
## using github link for load the data
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price
# 0       el           98.14

# %% [markdown]
# Check first 5 rows of the dataset

# %%
df.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# check last 5 rows of the dataset

# %%
df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %% [markdown]
# Check type of the dataset

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Check null values in the dataset

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# 5. How many rows and columns are there in our Dataset?

# %%
rows, cols = df.shape

print(f"The data set has {rows} rows and {cols} columns")
# Out:
# The data set has 10000 rows and 14 columns

# %% [markdown]
# 6. Highest and Lowest Purchase Prices.

# %%
maxpp = df["Purchase Price"].max()
minpp = df["Purchase Price"].min()

print(f"The highest and lowest purchase price are {maxpp} dollars and {minpp} dollars")
# Out:
# The highest and lowest purchase price are 99.99 dollars and 0.0 dollars

# %% [markdown]
# 7. Average Purchase Price

# %%
avgpp = df["Purchase Price"].mean()

print(f"The average purchase price is {avgpp:.2f} dollars")
# Out:
# The average purchase price is 50.35 dollars

# %% [markdown]
# 8. How many people have French 'fr' as their Language?

# %%
row, _= df[df["Language"] == 'fr'].shape
print(f"There are {row} people with French as their language")
# Out:
# There are 1097 people with Frech as their language

# %% [markdown]
# 9. How many languages people have in total

# %%
languages = df["Language"].nunique()

print(f"There are a total of {languages} languages")
# Out:
# There are a total of 9 languages

# %% [markdown]
# 9. Job Title Contains Engineer or engineer

# %%
df[df["Job"].str.contains("Engineer", case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# How many number of people have job as manager?

# %%
managers = len(df[df["Job"].str.contains("Manager", case=False)])

print(f"There are {managers} people that are managers")
# Out:
# There are 785 people that are managers

# %% [markdown]
# 10. Find The Email of the person with the following IP Address: 132.207.160.22

# %%
the_person = df[df["IP Address"] == "132.207.160.22"]
the_email = the_person["Email"].iloc[0]


print(f"The email of that person is {the_email}")
# Out:
# The email of that person is amymiller@morales-harrison.com

# %% [markdown]
# 11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?

# %%
count = len(df[(df["CC Provider"] == "Mastercard") & (df["Purchase Price"] > 50)])

print(f"There are {count} people that uses Mastercard and made a purchase above 50")
# Out:
# There are 405 people that uses Mastercard and made a purchase above 50

# %% [markdown]
# 12. Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
the_person = df[df["Credit Card"] == 4664825258997302]
the_email = the_person["Email"].iloc[0]


print(f"The email of that person is {the_email}")
# Out:
# The email of that person is bberry@wright.net

# %% [markdown]
# 13. How many people purchase during the AM and how many people purchase during PM?

# %%
am_people = len(df[df["AM or PM"] == "AM"]) 
pm_people = len(df[df["AM or PM"] == "PM"])

print(f"There are {am_people} people purchase during the AM and {pm_people} people purchase during the PM ")
# Out:
# There are 4932 people purchase during the AM and 5068 people purchase during the PM

# %% [markdown]
# 14. How many people have a credit card that expires in 2020?

# %%
the_dates = pd.to_datetime(df["CC Exp Date"], format="%m/%y")

people_cc_expire = (the_dates.dt.year == 2020).sum()

print(f"There are {count} people whose credit card expires in 2020")
# Out:
# There are 988 people whose credit card expires in 2020

# %% [markdown]
# 15. What are the top 5 most popular email providers (e.g. [gmail.com](http://gmail.com/), [yahoo.com](http://yahoo.com/), etc...)

# %%
df["Email Provider"] = df["Email"].str.split("@").str[1]

top5_emails = df["Email Provider"].value_counts().head(5)

top5_emails
# Out:
# Email Provider
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
